# %%
import pycurl
import io
import pandas as pd
import datetime
from datetime import date

c = pycurl.Curl()
f = open("master_ticker_list", "r")
#f = open("ticker_list_short", "r")

# %%
# initialize list of dicts to store date, before creating frame
px_rows = []

for ticker in f:
    
    buffer = io.BytesIO()
    
    ticker = ticker.strip()
    print(ticker)
    local_url = "https://query1.finance.yahoo.com/v7/finance/download/"+ticker+"?period1=378604800&period2=1586476800&interval=1d&events=history"
    print(local_url)

    c.setopt(c.URL, local_url)
    c.setopt(c.WRITEDATA, buffer)
    c.perform()
    c.getinfo(pycurl.HTTP_CODE)
    
    full_text = ""
    full_text = buffer.getvalue().decode()
    buffer.flush()
    buffer.close()
    
    ## for each line, stripping out fields to create dict
    ## loading dict in bulk into frame is much more efficient than indexing a frame repeatedly
    
    lines = full_text.splitlines()
    for line in lines[1:]:
        #print("here",line.split(',')[1],len(line.split(',')[1]))
        if len(line.split(',')[0]) and len(line.split(',')[1]) and len(line.split(',')[2]) and len(line.split(',')[3]) and len(line.split(',')[4]) and len(line.split(',')[5]) and len(line.split(',')[6]) and line.split(',')[0] != 'null' and line.split(',')[1] != 'null' and line.split(',')[2] != 'null' and line.split(',')[3] != 'null' and line.split(',')[4] != 'null' and line.split(',')[5] != 'null' and line.split(',')[6] != 'null':
            local_date = datetime.datetime.strptime(line.split(',')[0], "%Y-%m-%d").date()
            px_dict = {
                "ticker": ticker,
                "date": local_date,
                "open": float(line.split(',')[1]),
                "high": float(line.split(',')[2]),
                "low": float(line.split(',')[3]),
                "close": float(line.split(',')[4]),
                "adj_close": float(line.split(',')[5]),
                "volume": int(line.split(',')[6]),
                "delta": (float(line.split(',')[4])) - float((line.split(',')[1])) 
            }
            px_rows.append(px_dict)

master_px_frame = pd.DataFrame(px_rows)
master_px_frame.describe()
master_px_frame.to_csv("master_px_frame")
# Out:
# A
# https://query1.finance.yahoo.com/v7/finance/download/A?period1=378604800&period2=1586476800&interval=1d&events=history
# AA
# https://query1.finance.yahoo.com/v7/finance/download/AA?period1=378604800&period2=1586476800&interval=1d&events=history
# AAC
# https://query1.finance.yahoo.com/v7/finance/download/AAC?period1=378604800&period2=1586476800&interval=1d&events=history
# AAL
# https://query1.finance.yahoo.com/v7/finance/download/AAL?period1=378604800&period2=1586476800&interval=1d&events=history
# AAN
# https://query1.finance.yahoo.com/v7/finance/download/AAN?period1=378604800&period2=1586476800&interval=1d&events=history
# AAOI
# https://query1.finance.yahoo.com/v7/finance/download/AAOI?period1=378604800&period2=1586476800&interval=1d&events=history
# AAON
# https://query1.finance.yahoo.com/v7/finance/download/AAON?period1=378604800&period2=1586476800&interval=1d&events=history
# AAP
# https://query1.finance.yahoo.com/v7/finance/download/AAP?period1=378604800&period2=1586476800&interval=1d&events=history
# AAPL
# https://query1.finance.yahoo.com/v7/finance/download/AAPL?period1=378604800&period2=1586476800&interval=1d&events=history
# AAT
# https://query1.finance.yahoo.com/v7/finance/download/AAT?period1=378604800&period2=1586476800&interval=1d&events=history
# AAWW
# https://query1.finance.yahoo.com/v7/finance/download/AAWW?period1=378604800&period2=1586476800&interval=1d&events=history
# AAXN
# https://query1.finance.yahoo.com/v7/finance/download/AAXN?period1=378604800&period2=1586476800&interval=1d&events=history
# ABAX
# https://query1.finance.yahoo.com/v7/finance/download/ABAX?period1=378604800&period2=1586476800&interval=1d&events=history
# ABB
# https://query1.finance.yahoo.com/v7/finance/download/ABB?period1=378604800&period2=1586476800&interval=1d&events=history
# ABBV
# https://query1.finance.yahoo.com/v7/finance/download/ABBV?period1=378604800&period2=1586476800&interval=1d&events=history
# ABC
# https://query1.finance.yahoo.com/v7/finance/download/ABC?period1=378604800&period2=1586476800&interval=1d&events=history
# ABCB
# https://query1.finance.yahoo.com/v7/finance/download/ABCB?period1=378604800&period2=1586476800&interval=1d&events=history
# ABCD
# https://query1.finance.yahoo.com/v7/finance/download/ABCD?period1=378604800&period2=1586476800&interval=1d&events=history
# ABCO
# https://query1.finance.yahoo.com/v7/finance/download/ABCO?period1=378604800&period2=1586476800&interval=1d&events=history
# ABEO
# https://query1.finance.yahoo.com/v7/finance/download/ABEO?period1=378604800&period2=1586476800&interval=1d&events=history
# ABG
# https://query1.finance.yahoo.com/v7/finance/download/ABG?period1=378604800&period2=1586476800&interval=1d&events=history
# ABM
# https://query1.finance.yahoo.com/v7/finance/download/ABM?period1=378604800&period2=1586476800&interval=1d&events=history
# ABMD
# https://query1.finance.yahoo.com/v7/finance/download/ABMD?period1=378604800&period2=1586476800&interval=1d&events=history
# ABT
# https://query1.finance.yahoo.com/v7/finance/download/ABT?period1=378604800&period2=1586476800&interval=1d&events=history
# ABTX
# https://query1.finance.yahoo.com/v7/finance/download/ABTX?period1=378604800&period2=1586476800&interval=1d&events=history
# AC
# https://query1.finance.yahoo.com/v7/finance/download/AC?period1=378604800&period2=1586476800&interval=1d&events=history
# ACAD
# https://query1.finance.yahoo.com/v7/finance/download/ACAD?period1=378604800&period2=1586476800&interval=1d&events=history
# ACBI
# https://query1.finance.yahoo.com/v7/finance/download/ACBI?period1=378604800&period2=1586476800&interval=1d&events=history
# ACC
# https://query1.finance.yahoo.com/v7/finance/download/ACC?period1=378604800&period2=1586476800&interval=1d&events=history
# ACCO
# https://query1.finance.yahoo.com/v7/finance/download/ACCO?period1=378604800&period2=1586476800&interval=1d&events=history
# ACET
# https://query1.finance.yahoo.com/v7/finance/download/ACET?period1=378604800&period2=1586476800&interval=1d&events=history
# ACGL
# https://query1.finance.yahoo.com/v7/finance/download/ACGL?period1=378604800&period2=1586476800&interval=1d&events=history
# ACHC
# https://query1.finance.yahoo.com/v7/finance/download/ACHC?period1=378604800&period2=1586476800&interval=1d&events=history
# ACHN
# https://query1.finance.yahoo.com/v7/finance/download/ACHN?period1=378604800&period2=1586476800&interval=1d&events=history
# ACIA
# https://query1.finance.yahoo.com/v7/finance/download/ACIA?period1=378604800&period2=1586476800&interval=1d&events=history
# ACIW
# https://query1.finance.yahoo.com/v7/finance/download/ACIW?period1=378604800&period2=1586476800&interval=1d&events=history
# ACLS
# https://query1.finance.yahoo.com/v7/finance/download/ACLS?period1=378604800&period2=1586476800&interval=1d&events=history
# ACM
# https://query1.finance.yahoo.com/v7/finance/download/ACM?period1=378604800&period2=1586476800&interval=1d&events=history
# ACN
# https://query1.finance.yahoo.com/v7/finance/download/ACN?period1=378604800&period2=1586476800&interval=1d&events=history
# ACNB
# https://query1.finance.yahoo.com/v7/finance/download/ACNB?period1=378604800&period2=1586476800&interval=1d&events=history
# ACOR
# https://query1.finance.yahoo.com/v7/finance/download/ACOR?period1=378604800&period2=1586476800&interval=1d&events=history
# ACRE
# https://query1.finance.yahoo.com/v7/finance/download/ACRE?period1=378604800&period2=1586476800&interval=1d&events=history
# ACRS
# https://query1.finance.yahoo.com/v7/finance/download/ACRS?period1=378604800&period2=1586476800&interval=1d&events=history
# ACTA
# https://query1.finance.yahoo.com/v7/finance/download/ACTA?period1=378604800&period2=1586476800&interval=1d&events=history
# ACTG
# https://query1.finance.yahoo.com/v7/finance/download/ACTG?period1=378604800&period2=1586476800&interval=1d&events=history
# ACXM
# https://query1.finance.yahoo.com/v7/finance/download/ACXM?period1=378604800&period2=1586476800&interval=1d&events=history
# ADBE
# https://query1.finance.yahoo.com/v7/finance/download/ADBE?period1=378604800&period2=1586476800&interval=1d&events=history
# ADC
# https://query1.finance.yahoo.com/v7/finance/download/ADC?period1=378604800&period2=1586476800&interval=1d&events=history
# ADES
# https://query1.finance.yahoo.com/v7/finance/download/ADES?period1=378604800&period2=1586476800&interval=1d&events=history
# ADI
# https://query1.finance.yahoo.com/v7/finance/download/ADI?period1=378604800&period2=1586476800&interval=1d&events=history
# ADM
# https://query1.finance.yahoo.com/v7/finance/download/ADM?period1=378604800&period2=1586476800&interval=1d&events=history
# ADMS
# https://query1.finance.yahoo.com/v7/finance/download/ADMS?period1=378604800&period2=1586476800&interval=1d&events=history
# ADNT
# https://query1.finance.yahoo.com/v7/finance/download/ADNT?period1=378604800&period2=1586476800&interval=1d&events=history
# ADP
# https://query1.finance.yahoo.com/v7/finance/download/ADP?period1=378604800&period2=1586476800&interval=1d&events=history
# ADRO
# https://query1.finance.yahoo.com/v7/finance/download/ADRO?period1=378604800&period2=1586476800&interval=1d&events=history
# ADS
# https://query1.finance.yahoo.com/v7/finance/download/ADS?period1=378604800&period2=1586476800&interval=1d&events=history
# ADSK
# https://query1.finance.yahoo.com/v7/finance/download/ADSK?period1=378604800&period2=1586476800&interval=1d&events=history
# ADSW
# https://query1.finance.yahoo.com/v7/finance/download/ADSW?period1=378604800&period2=1586476800&interval=1d&events=history
# ADT
# https://query1.finance.yahoo.com/v7/finance/download/ADT?period1=378604800&period2=1586476800&interval=1d&events=history
# ADTN
# https://query1.finance.yahoo.com/v7/finance/download/ADTN?period1=378604800&period2=1586476800&interval=1d&events=history
# ADUS
# https://query1.finance.yahoo.com/v7/finance/download/ADUS?period1=378604800&period2=1586476800&interval=1d&events=history
# ADXS
# https://query1.finance.yahoo.com/v7/finance/download/ADXS?period1=378604800&period2=1586476800&interval=1d&events=history
# AE
# https://query1.finance.yahoo.com/v7/finance/download/AE?period1=378604800&period2=1586476800&interval=1d&events=history
# AEE
# https://query1.finance.yahoo.com/v7/finance/download/AEE?period1=378604800&period2=1586476800&interval=1d&events=history
# AEG
# https://query1.finance.yahoo.com/v7/finance/download/AEG?period1=378604800&period2=1586476800&interval=1d&events=history
# AEGN
# https://query1.finance.yahoo.com/v7/finance/download/AEGN?period1=378604800&period2=1586476800&interval=1d&events=history
# AEIS
# https://query1.finance.yahoo.com/v7/finance/download/AEIS?period1=378604800&period2=1586476800&interval=1d&events=history
# AEL
# https://query1.finance.yahoo.com/v7/finance/download/AEL?period1=378604800&period2=1586476800&interval=1d&events=history
# AEO
# https://query1.finance.yahoo.com/v7/finance/download/AEO?period1=378604800&period2=1586476800&interval=1d&events=history
# AEP
# https://query1.finance.yahoo.com/v7/finance/download/AEP?period1=378604800&period2=1586476800&interval=1d&events=history
# AERI
# https://query1.finance.yahoo.com/v7/finance/download/AERI?period1=378604800&period2=1586476800&interval=1d&events=history
# AES
# https://query1.finance.yahoo.com/v7/finance/download/AES?period1=378604800&period2=1586476800&interval=1d&events=history
# AET
# https://query1.finance.yahoo.com/v7/finance/download/AET?period1=378604800&period2=1586476800&interval=1d&events=history
# AF
# https://query1.finance.yahoo.com/v7/finance/download/AF?period1=378604800&period2=1586476800&interval=1d&events=history
# AFAM
# https://query1.finance.yahoo.com/v7/finance/download/AFAM?period1=378604800&period2=1586476800&interval=1d&events=history
# AFG
# https://query1.finance.yahoo.com/v7/finance/download/AFG?period1=378604800&period2=1586476800&interval=1d&events=history
# AFH
# https://query1.finance.yahoo.com/v7/finance/download/AFH?period1=378604800&period2=1586476800&interval=1d&events=history
# AFI
# https://query1.finance.yahoo.com/v7/finance/download/AFI?period1=378604800&period2=1586476800&interval=1d&events=history
# AFL
# https://query1.finance.yahoo.com/v7/finance/download/AFL?period1=378604800&period2=1586476800&interval=1d&events=history
# AFSI
# https://query1.finance.yahoo.com/v7/finance/download/AFSI?period1=378604800&period2=1586476800&interval=1d&events=history
# AGCO
# https://query1.finance.yahoo.com/v7/finance/download/AGCO?period1=378604800&period2=1586476800&interval=1d&events=history
# AGEN
# https://query1.finance.yahoo.com/v7/finance/download/AGEN?period1=378604800&period2=1586476800&interval=1d&events=history
# AGFS
# https://query1.finance.yahoo.com/v7/finance/download/AGFS?period1=378604800&period2=1586476800&interval=1d&events=history
# AGII
# https://query1.finance.yahoo.com/v7/finance/download/AGII?period1=378604800&period2=1586476800&interval=1d&events=history
# AGIO
# https://query1.finance.yahoo.com/v7/finance/download/AGIO?period1=378604800&period2=1586476800&interval=1d&events=history
# AGM
# https://query1.finance.yahoo.com/v7/finance/download/AGM?period1=378604800&period2=1586476800&interval=1d&events=history
# AGN
# https://query1.finance.yahoo.com/v7/finance/download/AGN?period1=378604800&period2=1586476800&interval=1d&events=history
# AGNC
# https://query1.finance.yahoo.com/v7/finance/download/AGNC?period1=378604800&period2=1586476800&interval=1d&events=history
# AGO
# https://query1.finance.yahoo.com/v7/finance/download/AGO?period1=378604800&period2=1586476800&interval=1d&events=history
# AGR
# https://query1.finance.yahoo.com/v7/finance/download/AGR?period1=378604800&period2=1586476800&interval=1d&events=history
# AGX
# https://query1.finance.yahoo.com/v7/finance/download/AGX?period1=378604800&period2=1586476800&interval=1d&events=history
# AGYS
# https://query1.finance.yahoo.com/v7/finance/download/AGYS?period1=378604800&period2=1586476800&interval=1d&events=history
# AHH
# https://query1.finance.yahoo.com/v7/finance/download/AHH?period1=378604800&period2=1586476800&interval=1d&events=history
# AHL
# https://query1.finance.yahoo.com/v7/finance/download/AHL?period1=378604800&period2=1586476800&interval=1d&events=history
# AHP
# https://query1.finance.yahoo.com/v7/finance/download/AHP?period1=378604800&period2=1586476800&interval=1d&events=history
# AHT
# https://query1.finance.yahoo.com/v7/finance/download/AHT?period1=378604800&period2=1586476800&interval=1d&events=history
# AI
# https://query1.finance.yahoo.com/v7/finance/download/AI?period1=378604800&period2=1586476800&interval=1d&events=history
# AIG
# https://query1.finance.yahoo.com/v7/finance/download/AIG?period1=378604800&period2=1586476800&interval=1d&events=history
# AIMC
# https://query1.finance.yahoo.com/v7/finance/download/AIMC?period1=378604800&period2=1586476800&interval=1d&events=history
# AIMT
# https://query1.finance.yahoo.com/v7/finance/download/AIMT?period1=378604800&period2=1586476800&interval=1d&events=history
# AIN
# https://query1.finance.yahoo.com/v7/finance/download/AIN?period1=378604800&period2=1586476800&interval=1d&events=history
# AIR
# https://query1.finance.yahoo.com/v7/finance/download/AIR?period1=378604800&period2=1586476800&interval=1d&events=history
# AIT
# https://query1.finance.yahoo.com/v7/finance/download/AIT?period1=378604800&period2=1586476800&interval=1d&events=history
# AIV
# https://query1.finance.yahoo.com/v7/finance/download/AIV?period1=378604800&period2=1586476800&interval=1d&events=history
# AIZ
# https://query1.finance.yahoo.com/v7/finance/download/AIZ?period1=378604800&period2=1586476800&interval=1d&events=history
# AJG
# https://query1.finance.yahoo.com/v7/finance/download/AJG?period1=378604800&period2=1586476800&interval=1d&events=history
# AJRD
# https://query1.finance.yahoo.com/v7/finance/download/AJRD?period1=378604800&period2=1586476800&interval=1d&events=history
# AJX
# https://query1.finance.yahoo.com/v7/finance/download/AJX?period1=378604800&period2=1586476800&interval=1d&events=history
# AKAM
# https://query1.finance.yahoo.com/v7/finance/download/AKAM?period1=378604800&period2=1586476800&interval=1d&events=history
# AKAO
# https://query1.finance.yahoo.com/v7/finance/download/AKAO?period1=378604800&period2=1586476800&interval=1d&events=history
# AKBA
# https://query1.finance.yahoo.com/v7/finance/download/AKBA?period1=378604800&period2=1586476800&interval=1d&events=history
# AKR
# https://query1.finance.yahoo.com/v7/finance/download/AKR?period1=378604800&period2=1586476800&interval=1d&events=history
# AKRX
# https://query1.finance.yahoo.com/v7/finance/download/AKRX?period1=378604800&period2=1586476800&interval=1d&events=history
# AKS
# https://query1.finance.yahoo.com/v7/finance/download/AKS?period1=378604800&period2=1586476800&interval=1d&events=history
# AKTS
# https://query1.finance.yahoo.com/v7/finance/download/AKTS?period1=378604800&period2=1586476800&interval=1d&events=history
# AL
# https://query1.finance.yahoo.com/v7/finance/download/AL?period1=378604800&period2=1586476800&interval=1d&events=history
# ALB
# https://query1.finance.yahoo.com/v7/finance/download/ALB?period1=378604800&period2=1586476800&interval=1d&events=history
# ALCO
# https://query1.finance.yahoo.com/v7/finance/download/ALCO?period1=378604800&period2=1586476800&interval=1d&events=history
# ALDR
# https://query1.finance.yahoo.com/v7/finance/download/ALDR?period1=378604800&period2=1586476800&interval=1d&events=history
# ALE
# https://query1.finance.yahoo.com/v7/finance/download/ALE?period1=378604800&period2=1586476800&interval=1d&events=history
# ALEX
# https://query1.finance.yahoo.com/v7/finance/download/ALEX?period1=378604800&period2=1586476800&interval=1d&events=history
# ALG
# https://query1.finance.yahoo.com/v7/finance/download/ALG?period1=378604800&period2=1586476800&interval=1d&events=history
# ALGN
# https://query1.finance.yahoo.com/v7/finance/download/ALGN?period1=378604800&period2=1586476800&interval=1d&events=history
# ALGT
# https://query1.finance.yahoo.com/v7/finance/download/ALGT?period1=378604800&period2=1586476800&interval=1d&events=history
# ALJ
# https://query1.finance.yahoo.com/v7/finance/download/ALJ?period1=378604800&period2=1586476800&interval=1d&events=history
# ALK
# https://query1.finance.yahoo.com/v7/finance/download/ALK?period1=378604800&period2=1586476800&interval=1d&events=history
# ALKS
# https://query1.finance.yahoo.com/v7/finance/download/ALKS?period1=378604800&period2=1586476800&interval=1d&events=history
# ALL
# https://query1.finance.yahoo.com/v7/finance/download/ALL?period1=378604800&period2=1586476800&interval=1d&events=history
# ALLE
# https://query1.finance.yahoo.com/v7/finance/download/ALLE?period1=378604800&period2=1586476800&interval=1d&events=history
# ALLY
# https://query1.finance.yahoo.com/v7/finance/download/ALLY?period1=378604800&period2=1586476800&interval=1d&events=history
# ALNY
# https://query1.finance.yahoo.com/v7/finance/download/ALNY?period1=378604800&period2=1586476800&interval=1d&events=history
# ALOG
# https://query1.finance.yahoo.com/v7/finance/download/ALOG?period1=378604800&period2=1586476800&interval=1d&events=history
# ALR
# https://query1.finance.yahoo.com/v7/finance/download/ALR?period1=378604800&period2=1586476800&interval=1d&events=history
# ALRM
# https://query1.finance.yahoo.com/v7/finance/download/ALRM?period1=378604800&period2=1586476800&interval=1d&events=history
# ALSN
# https://query1.finance.yahoo.com/v7/finance/download/ALSN?period1=378604800&period2=1586476800&interval=1d&events=history
# ALV
# https://query1.finance.yahoo.com/v7/finance/download/ALV?period1=378604800&period2=1586476800&interval=1d&events=history
# ALX
# https://query1.finance.yahoo.com/v7/finance/download/ALX?period1=378604800&period2=1586476800&interval=1d&events=history
# ALXN
# https://query1.finance.yahoo.com/v7/finance/download/ALXN?period1=378604800&period2=1586476800&interval=1d&events=history
# AMAG
# https://query1.finance.yahoo.com/v7/finance/download/AMAG?period1=378604800&period2=1586476800&interval=1d&events=history
# AMAT
# https://query1.finance.yahoo.com/v7/finance/download/AMAT?period1=378604800&period2=1586476800&interval=1d&events=history
# AMBA
# https://query1.finance.yahoo.com/v7/finance/download/AMBA?period1=378604800&period2=1586476800&interval=1d&events=history
# AMBC
# https://query1.finance.yahoo.com/v7/finance/download/AMBC?period1=378604800&period2=1586476800&interval=1d&events=history
# AMBR
# https://query1.finance.yahoo.com/v7/finance/download/AMBR?period1=378604800&period2=1586476800&interval=1d&events=history
# AMC
# https://query1.finance.yahoo.com/v7/finance/download/AMC?period1=378604800&period2=1586476800&interval=1d&events=history
# AMCR
# https://query1.finance.yahoo.com/v7/finance/download/AMCR?period1=378604800&period2=1586476800&interval=1d&events=history
# AMCX
# https://query1.finance.yahoo.com/v7/finance/download/AMCX?period1=378604800&period2=1586476800&interval=1d&events=history
# AMD
# https://query1.finance.yahoo.com/v7/finance/download/AMD?period1=378604800&period2=1586476800&interval=1d&events=history
# AME
# https://query1.finance.yahoo.com/v7/finance/download/AME?period1=378604800&period2=1586476800&interval=1d&events=history
# AMED
# https://query1.finance.yahoo.com/v7/finance/download/AMED?period1=378604800&period2=1586476800&interval=1d&events=history
# AMG
# https://query1.finance.yahoo.com/v7/finance/download/AMG?period1=378604800&period2=1586476800&interval=1d&events=history
# AMGN
# https://query1.finance.yahoo.com/v7/finance/download/AMGN?period1=378604800&period2=1586476800&interval=1d&events=history
# AMH
# https://query1.finance.yahoo.com/v7/finance/download/AMH?period1=378604800&period2=1586476800&interval=1d&events=history
# AMKR
# https://query1.finance.yahoo.com/v7/finance/download/AMKR?period1=378604800&period2=1586476800&interval=1d&events=history
# AMN
# https://query1.finance.yahoo.com/v7/finance/download/AMN?period1=378604800&period2=1586476800&interval=1d&events=history
# AMNB
# https://query1.finance.yahoo.com/v7/finance/download/AMNB?period1=378604800&period2=1586476800&interval=1d&events=history
# AMOT
# https://query1.finance.yahoo.com/v7/finance/download/AMOT?period1=378604800&period2=1586476800&interval=1d&events=history
# AMP
# https://query1.finance.yahoo.com/v7/finance/download/AMP?period1=378604800&period2=1586476800&interval=1d&events=history
# AMPH
# https://query1.finance.yahoo.com/v7/finance/download/AMPH?period1=378604800&period2=1586476800&interval=1d&events=history
# AMRC
# https://query1.finance.yahoo.com/v7/finance/download/AMRC?period1=378604800&period2=1586476800&interval=1d&events=history
# AMRI
# https://query1.finance.yahoo.com/v7/finance/download/AMRI?period1=378604800&period2=1586476800&interval=1d&events=history
# AMSF
# https://query1.finance.yahoo.com/v7/finance/download/AMSF?period1=378604800&period2=1586476800&interval=1d&events=history
# AMSWA
# https://query1.finance.yahoo.com/v7/finance/download/AMSWA?period1=378604800&period2=1586476800&interval=1d&events=history
# AMT
# https://query1.finance.yahoo.com/v7/finance/download/AMT?period1=378604800&period2=1586476800&interval=1d&events=history
# AMTD
# https://query1.finance.yahoo.com/v7/finance/download/AMTD?period1=378604800&period2=1586476800&interval=1d&events=history
# AMWD
# https://query1.finance.yahoo.com/v7/finance/download/AMWD?period1=378604800&period2=1586476800&interval=1d&events=history
# AMZN
# https://query1.finance.yahoo.com/v7/finance/download/AMZN?period1=378604800&period2=1586476800&interval=1d&events=history
# AN
# https://query1.finance.yahoo.com/v7/finance/download/AN?period1=378604800&period2=1586476800&interval=1d&events=history
# ANAB
# https://query1.finance.yahoo.com/v7/finance/download/ANAB?period1=378604800&period2=1586476800&interval=1d&events=history
# ANAT
# https://query1.finance.yahoo.com/v7/finance/download/ANAT?period1=378604800&period2=1586476800&interval=1d&events=history
# ANCX
# https://query1.finance.yahoo.com/v7/finance/download/ANCX?period1=378604800&period2=1586476800&interval=1d&events=history
# ANDE
# https://query1.finance.yahoo.com/v7/finance/download/ANDE?period1=378604800&period2=1586476800&interval=1d&events=history
# ANET
# https://query1.finance.yahoo.com/v7/finance/download/ANET?period1=378604800&period2=1586476800&interval=1d&events=history
# ANF
# https://query1.finance.yahoo.com/v7/finance/download/ANF?period1=378604800&period2=1586476800&interval=1d&events=history
# ANGI
# https://query1.finance.yahoo.com/v7/finance/download/ANGI?period1=378604800&period2=1586476800&interval=1d&events=history
# ANGO
# https://query1.finance.yahoo.com/v7/finance/download/ANGO?period1=378604800&period2=1586476800&interval=1d&events=history
# ANH
# https://query1.finance.yahoo.com/v7/finance/download/ANH?period1=378604800&period2=1586476800&interval=1d&events=history
# ANIK
# https://query1.finance.yahoo.com/v7/finance/download/ANIK?period1=378604800&period2=1586476800&interval=1d&events=history
# ANIP
# https://query1.finance.yahoo.com/v7/finance/download/ANIP?period1=378604800&period2=1586476800&interval=1d&events=history
# ANSS
# https://query1.finance.yahoo.com/v7/finance/download/ANSS?period1=378604800&period2=1586476800&interval=1d&events=history
# ANTM
# https://query1.finance.yahoo.com/v7/finance/download/ANTM?period1=378604800&period2=1586476800&interval=1d&events=history
# AOBC
# https://query1.finance.yahoo.com/v7/finance/download/AOBC?period1=378604800&period2=1586476800&interval=1d&events=history
# AON
# https://query1.finance.yahoo.com/v7/finance/download/AON?period1=378604800&period2=1586476800&interval=1d&events=history
# AOS
# https://query1.finance.yahoo.com/v7/finance/download/AOS?period1=378604800&period2=1586476800&interval=1d&events=history
# AOSL
# https://query1.finance.yahoo.com/v7/finance/download/AOSL?period1=378604800&period2=1586476800&interval=1d&events=history
# AP
# https://query1.finance.yahoo.com/v7/finance/download/AP?period1=378604800&period2=1586476800&interval=1d&events=history
# APA
# https://query1.finance.yahoo.com/v7/finance/download/APA?period1=378604800&period2=1586476800&interval=1d&events=history
# APAM
# https://query1.finance.yahoo.com/v7/finance/download/APAM?period1=378604800&period2=1586476800&interval=1d&events=history
# APC
# https://query1.finance.yahoo.com/v7/finance/download/APC?period1=378604800&period2=1586476800&interval=1d&events=history
# APD
# https://query1.finance.yahoo.com/v7/finance/download/APD?period1=378604800&period2=1586476800&interval=1d&events=history
# APEI
# https://query1.finance.yahoo.com/v7/finance/download/APEI?period1=378604800&period2=1586476800&interval=1d&events=history
# APH
# https://query1.finance.yahoo.com/v7/finance/download/APH?period1=378604800&period2=1586476800&interval=1d&events=history
# APLE
# https://query1.finance.yahoo.com/v7/finance/download/APLE?period1=378604800&period2=1586476800&interval=1d&events=history
# APOG
# https://query1.finance.yahoo.com/v7/finance/download/APOG?period1=378604800&period2=1586476800&interval=1d&events=history
# APPF
# https://query1.finance.yahoo.com/v7/finance/download/APPF?period1=378604800&period2=1586476800&interval=1d&events=history
# APTI
# https://query1.finance.yahoo.com/v7/finance/download/APTI?period1=378604800&period2=1586476800&interval=1d&events=history
# APTS
# https://query1.finance.yahoo.com/v7/finance/download/APTS?period1=378604800&period2=1586476800&interval=1d&events=history
# APTV
# https://query1.finance.yahoo.com/v7/finance/download/APTV?period1=378604800&period2=1586476800&interval=1d&events=history
# AQMS
# https://query1.finance.yahoo.com/v7/finance/download/AQMS?period1=378604800&period2=1586476800&interval=1d&events=history
# AR
# https://query1.finance.yahoo.com/v7/finance/download/AR?period1=378604800&period2=1586476800&interval=1d&events=history
# ARA
# https://query1.finance.yahoo.com/v7/finance/download/ARA?period1=378604800&period2=1586476800&interval=1d&events=history
# ARAY
# https://query1.finance.yahoo.com/v7/finance/download/ARAY?period1=378604800&period2=1586476800&interval=1d&events=history
# ARC
# https://query1.finance.yahoo.com/v7/finance/download/ARC?period1=378604800&period2=1586476800&interval=1d&events=history
# ARCB
# https://query1.finance.yahoo.com/v7/finance/download/ARCB?period1=378604800&period2=1586476800&interval=1d&events=history
# ARCH
# https://query1.finance.yahoo.com/v7/finance/download/ARCH?period1=378604800&period2=1586476800&interval=1d&events=history
# ARCO
# https://query1.finance.yahoo.com/v7/finance/download/ARCO?period1=378604800&period2=1586476800&interval=1d&events=history
# ARD
# https://query1.finance.yahoo.com/v7/finance/download/ARD?period1=378604800&period2=1586476800&interval=1d&events=history
# ARDX
# https://query1.finance.yahoo.com/v7/finance/download/ARDX?period1=378604800&period2=1586476800&interval=1d&events=history
# ARE
# https://query1.finance.yahoo.com/v7/finance/download/ARE?period1=378604800&period2=1586476800&interval=1d&events=history
# AREX
# https://query1.finance.yahoo.com/v7/finance/download/AREX?period1=378604800&period2=1586476800&interval=1d&events=history
# ARI
# https://query1.finance.yahoo.com/v7/finance/download/ARI?period1=378604800&period2=1586476800&interval=1d&events=history
# ARII
# https://query1.finance.yahoo.com/v7/finance/download/ARII?period1=378604800&period2=1586476800&interval=1d&events=history
# ARMK
# https://query1.finance.yahoo.com/v7/finance/download/ARMK?period1=378604800&period2=1586476800&interval=1d&events=history
# ARNA
# https://query1.finance.yahoo.com/v7/finance/download/ARNA?period1=378604800&period2=1586476800&interval=1d&events=history
# ARNC
# https://query1.finance.yahoo.com/v7/finance/download/ARNC?period1=378604800&period2=1586476800&interval=1d&events=history
# AROC
# https://query1.finance.yahoo.com/v7/finance/download/AROC?period1=378604800&period2=1586476800&interval=1d&events=history
# AROW
# https://query1.finance.yahoo.com/v7/finance/download/AROW?period1=378604800&period2=1586476800&interval=1d&events=history
# ARR
# https://query1.finance.yahoo.com/v7/finance/download/ARR?period1=378604800&period2=1586476800&interval=1d&events=history
# ARRS
# https://query1.finance.yahoo.com/v7/finance/download/ARRS?period1=378604800&period2=1586476800&interval=1d&events=history
# ARRY
# https://query1.finance.yahoo.com/v7/finance/download/ARRY?period1=378604800&period2=1586476800&interval=1d&events=history
# ARTNA
# https://query1.finance.yahoo.com/v7/finance/download/ARTNA?period1=378604800&period2=1586476800&interval=1d&events=history
# ARW
# https://query1.finance.yahoo.com/v7/finance/download/ARW?period1=378604800&period2=1586476800&interval=1d&events=history
# ASB
# https://query1.finance.yahoo.com/v7/finance/download/ASB?period1=378604800&period2=1586476800&interval=1d&events=history
# ASBB
# https://query1.finance.yahoo.com/v7/finance/download/ASBB?period1=378604800&period2=1586476800&interval=1d&events=history
# ASC
# https://query1.finance.yahoo.com/v7/finance/download/ASC?period1=378604800&period2=1586476800&interval=1d&events=history
# ASCMA
# https://query1.finance.yahoo.com/v7/finance/download/ASCMA?period1=378604800&period2=1586476800&interval=1d&events=history
# ASGN
# https://query1.finance.yahoo.com/v7/finance/download/ASGN?period1=378604800&period2=1586476800&interval=1d&events=history
# ASH
# https://query1.finance.yahoo.com/v7/finance/download/ASH?period1=378604800&period2=1586476800&interval=1d&events=history
# ASIX
# https://query1.finance.yahoo.com/v7/finance/download/ASIX?period1=378604800&period2=1586476800&interval=1d&events=history
# ASMB
# https://query1.finance.yahoo.com/v7/finance/download/ASMB?period1=378604800&period2=1586476800&interval=1d&events=history
# ASNA
# https://query1.finance.yahoo.com/v7/finance/download/ASNA?period1=378604800&period2=1586476800&interval=1d&events=history
# ASPS
# https://query1.finance.yahoo.com/v7/finance/download/ASPS?period1=378604800&period2=1586476800&interval=1d&events=history
# AST
# https://query1.finance.yahoo.com/v7/finance/download/AST?period1=378604800&period2=1586476800&interval=1d&events=history
# ASTE
# https://query1.finance.yahoo.com/v7/finance/download/ASTE?period1=378604800&period2=1586476800&interval=1d&events=history
# AT
# https://query1.finance.yahoo.com/v7/finance/download/AT?period1=378604800&period2=1586476800&interval=1d&events=history
# ATCO
# https://query1.finance.yahoo.com/v7/finance/download/ATCO?period1=378604800&period2=1586476800&interval=1d&events=history
# ATEN
# https://query1.finance.yahoo.com/v7/finance/download/ATEN?period1=378604800&period2=1586476800&interval=1d&events=history
# ATGE
# https://query1.finance.yahoo.com/v7/finance/download/ATGE?period1=378604800&period2=1586476800&interval=1d&events=history
# ATH
# https://query1.finance.yahoo.com/v7/finance/download/ATH?period1=378604800&period2=1586476800&interval=1d&events=history
# ATHN
# https://query1.finance.yahoo.com/v7/finance/download/ATHN?period1=378604800&period2=1586476800&interval=1d&events=history
# ATHX
# https://query1.finance.yahoo.com/v7/finance/download/ATHX?period1=378604800&period2=1586476800&interval=1d&events=history
# ATI
# https://query1.finance.yahoo.com/v7/finance/download/ATI?period1=378604800&period2=1586476800&interval=1d&events=history
# ATKR
# https://query1.finance.yahoo.com/v7/finance/download/ATKR?period1=378604800&period2=1586476800&interval=1d&events=history
# ATLO
# https://query1.finance.yahoo.com/v7/finance/download/ATLO?period1=378604800&period2=1586476800&interval=1d&events=history
# ATNI
# https://query1.finance.yahoo.com/v7/finance/download/ATNI?period1=378604800&period2=1586476800&interval=1d&events=history
# ATO
# https://query1.finance.yahoo.com/v7/finance/download/ATO?period1=378604800&period2=1586476800&interval=1d&events=history
# ATR
# https://query1.finance.yahoo.com/v7/finance/download/ATR?period1=378604800&period2=1586476800&interval=1d&events=history
# ATRA
# https://query1.finance.yahoo.com/v7/finance/download/ATRA?period1=378604800&period2=1586476800&interval=1d&events=history
# ATRC
# https://query1.finance.yahoo.com/v7/finance/download/ATRC?period1=378604800&period2=1586476800&interval=1d&events=history
# ATRI
# https://query1.finance.yahoo.com/v7/finance/download/ATRI?period1=378604800&period2=1586476800&interval=1d&events=history
# ATRO
# https://query1.finance.yahoo.com/v7/finance/download/ATRO?period1=378604800&period2=1586476800&interval=1d&events=history
# ATRS
# https://query1.finance.yahoo.com/v7/finance/download/ATRS?period1=378604800&period2=1586476800&interval=1d&events=history
# ATSG
# https://query1.finance.yahoo.com/v7/finance/download/ATSG?period1=378604800&period2=1586476800&interval=1d&events=history
# ATU
# https://query1.finance.yahoo.com/v7/finance/download/ATU?period1=378604800&period2=1586476800&interval=1d&events=history
# ATVI
# https://query1.finance.yahoo.com/v7/finance/download/ATVI?period1=378604800&period2=1586476800&interval=1d&events=history
# ATW
# https://query1.finance.yahoo.com/v7/finance/download/ATW?period1=378604800&period2=1586476800&interval=1d&events=history
# AUB
# https://query1.finance.yahoo.com/v7/finance/download/AUB?period1=378604800&period2=1586476800&interval=1d&events=history
# AVA
# https://query1.finance.yahoo.com/v7/finance/download/AVA?period1=378604800&period2=1586476800&interval=1d&events=history
# AVAV
# https://query1.finance.yahoo.com/v7/finance/download/AVAV?period1=378604800&period2=1586476800&interval=1d&events=history
# AVB
# https://query1.finance.yahoo.com/v7/finance/download/AVB?period1=378604800&period2=1586476800&interval=1d&events=history
# AVD
# https://query1.finance.yahoo.com/v7/finance/download/AVD?period1=378604800&period2=1586476800&interval=1d&events=history
# AVGO
# https://query1.finance.yahoo.com/v7/finance/download/AVGO?period1=378604800&period2=1586476800&interval=1d&events=history
# AVHI
# https://query1.finance.yahoo.com/v7/finance/download/AVHI?period1=378604800&period2=1586476800&interval=1d&events=history
# AVID
# https://query1.finance.yahoo.com/v7/finance/download/AVID?period1=378604800&period2=1586476800&interval=1d&events=history
# AVT
# https://query1.finance.yahoo.com/v7/finance/download/AVT?period1=378604800&period2=1586476800&interval=1d&events=history
# AVX
# https://query1.finance.yahoo.com/v7/finance/download/AVX?period1=378604800&period2=1586476800&interval=1d&events=history
# AVXL
# https://query1.finance.yahoo.com/v7/finance/download/AVXL?period1=378604800&period2=1586476800&interval=1d&events=history
# AVXS
# https://query1.finance.yahoo.com/v7/finance/download/AVXS?period1=378604800&period2=1586476800&interval=1d&events=history
# AVY
# https://query1.finance.yahoo.com/v7/finance/download/AVY?period1=378604800&period2=1586476800&interval=1d&events=history
# AWH
# https://query1.finance.yahoo.com/v7/finance/download/AWH?period1=378604800&period2=1586476800&interval=1d&events=history
# AWI
# https://query1.finance.yahoo.com/v7/finance/download/AWI?period1=378604800&period2=1586476800&interval=1d&events=history
# AWK
# https://query1.finance.yahoo.com/v7/finance/download/AWK?period1=378604800&period2=1586476800&interval=1d&events=history
# AWR
# https://query1.finance.yahoo.com/v7/finance/download/AWR?period1=378604800&period2=1586476800&interval=1d&events=history
# AXAS
# https://query1.finance.yahoo.com/v7/finance/download/AXAS?period1=378604800&period2=1586476800&interval=1d&events=history
# AXDX
# https://query1.finance.yahoo.com/v7/finance/download/AXDX?period1=378604800&period2=1586476800&interval=1d&events=history
# AXE
# https://query1.finance.yahoo.com/v7/finance/download/AXE?period1=378604800&period2=1586476800&interval=1d&events=history
# AXGN
# https://query1.finance.yahoo.com/v7/finance/download/AXGN?period1=378604800&period2=1586476800&interval=1d&events=history
# AXL
# https://query1.finance.yahoo.com/v7/finance/download/AXL?period1=378604800&period2=1586476800&interval=1d&events=history
# AXON
# https://query1.finance.yahoo.com/v7/finance/download/AXON?period1=378604800&period2=1586476800&interval=1d&events=history
# AXP
# https://query1.finance.yahoo.com/v7/finance/download/AXP?period1=378604800&period2=1586476800&interval=1d&events=history
# AXS
# https://query1.finance.yahoo.com/v7/finance/download/AXS?period1=378604800&period2=1586476800&interval=1d&events=history
# AXTA
# https://query1.finance.yahoo.com/v7/finance/download/AXTA?period1=378604800&period2=1586476800&interval=1d&events=history
# AXTI
# https://query1.finance.yahoo.com/v7/finance/download/AXTI?period1=378604800&period2=1586476800&interval=1d&events=history
# AY
# https://query1.finance.yahoo.com/v7/finance/download/AY?period1=378604800&period2=1586476800&interval=1d&events=history
# AYI
# https://query1.finance.yahoo.com/v7/finance/download/AYI?period1=378604800&period2=1586476800&interval=1d&events=history
# AYR
# https://query1.finance.yahoo.com/v7/finance/download/AYR?period1=378604800&period2=1586476800&interval=1d&events=history
# AYX
# https://query1.finance.yahoo.com/v7/finance/download/AYX?period1=378604800&period2=1586476800&interval=1d&events=history
# AZO
# https://query1.finance.yahoo.com/v7/finance/download/AZO?period1=378604800&period2=1586476800&interval=1d&events=history
# AZPN
# https://query1.finance.yahoo.com/v7/finance/download/AZPN?period1=378604800&period2=1586476800&interval=1d&events=history
# AZZ
# https://query1.finance.yahoo.com/v7/finance/download/AZZ?period1=378604800&period2=1586476800&interval=1d&events=history
# B
# https://query1.finance.yahoo.com/v7/finance/download/B?period1=378604800&period2=1586476800&interval=1d&events=history
# BA
# https://query1.finance.yahoo.com/v7/finance/download/BA?period1=378604800&period2=1586476800&interval=1d&events=history
# BABY
# https://query1.finance.yahoo.com/v7/finance/download/BABY?period1=378604800&period2=1586476800&interval=1d&events=history
# BAC
# https://query1.finance.yahoo.com/v7/finance/download/BAC?period1=378604800&period2=1586476800&interval=1d&events=history
# BAH
# https://query1.finance.yahoo.com/v7/finance/download/BAH?period1=378604800&period2=1586476800&interval=1d&events=history
# BANC
# https://query1.finance.yahoo.com/v7/finance/download/BANC?period1=378604800&period2=1586476800&interval=1d&events=history
# BANF
# https://query1.finance.yahoo.com/v7/finance/download/BANF?period1=378604800&period2=1586476800&interval=1d&events=history
# BANR
# https://query1.finance.yahoo.com/v7/finance/download/BANR?period1=378604800&period2=1586476800&interval=1d&events=history
# BAS
# https://query1.finance.yahoo.com/v7/finance/download/BAS?period1=378604800&period2=1586476800&interval=1d&events=history
# BATRA
# https://query1.finance.yahoo.com/v7/finance/download/BATRA?period1=378604800&period2=1586476800&interval=1d&events=history
# BATRK
# https://query1.finance.yahoo.com/v7/finance/download/BATRK?period1=378604800&period2=1586476800&interval=1d&events=history
# BAX
# https://query1.finance.yahoo.com/v7/finance/download/BAX?period1=378604800&period2=1586476800&interval=1d&events=history
# BBBY
# https://query1.finance.yahoo.com/v7/finance/download/BBBY?period1=378604800&period2=1586476800&interval=1d&events=history
# BBG
# https://query1.finance.yahoo.com/v7/finance/download/BBG?period1=378604800&period2=1586476800&interval=1d&events=history
# BBGI
# https://query1.finance.yahoo.com/v7/finance/download/BBGI?period1=378604800&period2=1586476800&interval=1d&events=history
# BBL
# https://query1.finance.yahoo.com/v7/finance/download/BBL?period1=378604800&period2=1586476800&interval=1d&events=history
# BBSI
# https://query1.finance.yahoo.com/v7/finance/download/BBSI?period1=378604800&period2=1586476800&interval=1d&events=history
# BBT
# https://query1.finance.yahoo.com/v7/finance/download/BBT?period1=378604800&period2=1586476800&interval=1d&events=history
# BBVA
# https://query1.finance.yahoo.com/v7/finance/download/BBVA?period1=378604800&period2=1586476800&interval=1d&events=history
# BBW
# https://query1.finance.yahoo.com/v7/finance/download/BBW?period1=378604800&period2=1586476800&interval=1d&events=history
# BBY
# https://query1.finance.yahoo.com/v7/finance/download/BBY?period1=378604800&period2=1586476800&interval=1d&events=history
# BC
# https://query1.finance.yahoo.com/v7/finance/download/BC?period1=378604800&period2=1586476800&interval=1d&events=history
# BCBP
# https://query1.finance.yahoo.com/v7/finance/download/BCBP?period1=378604800&period2=1586476800&interval=1d&events=history
# BCC
# https://query1.finance.yahoo.com/v7/finance/download/BCC?period1=378604800&period2=1586476800&interval=1d&events=history
# BCEI
# https://query1.finance.yahoo.com/v7/finance/download/BCEI?period1=378604800&period2=1586476800&interval=1d&events=history
# BCO
# https://query1.finance.yahoo.com/v7/finance/download/BCO?period1=378604800&period2=1586476800&interval=1d&events=history
# BCOR
# https://query1.finance.yahoo.com/v7/finance/download/BCOR?period1=378604800&period2=1586476800&interval=1d&events=history
# BCOV
# https://query1.finance.yahoo.com/v7/finance/download/BCOV?period1=378604800&period2=1586476800&interval=1d&events=history
# BCPC
# https://query1.finance.yahoo.com/v7/finance/download/BCPC?period1=378604800&period2=1586476800&interval=1d&events=history
# BCR
# https://query1.finance.yahoo.com/v7/finance/download/BCR?period1=378604800&period2=1586476800&interval=1d&events=history
# BCRH
# https://query1.finance.yahoo.com/v7/finance/download/BCRH?period1=378604800&period2=1586476800&interval=1d&events=history
# BCRX
# https://query1.finance.yahoo.com/v7/finance/download/BCRX?period1=378604800&period2=1586476800&interval=1d&events=history
# BDC
# https://query1.finance.yahoo.com/v7/finance/download/BDC?period1=378604800&period2=1586476800&interval=1d&events=history
# BDE
# https://query1.finance.yahoo.com/v7/finance/download/BDE?period1=378604800&period2=1586476800&interval=1d&events=history
# BDGE
# https://query1.finance.yahoo.com/v7/finance/download/BDGE?period1=378604800&period2=1586476800&interval=1d&events=history
# BDN
# https://query1.finance.yahoo.com/v7/finance/download/BDN?period1=378604800&period2=1586476800&interval=1d&events=history
# BDX
# https://query1.finance.yahoo.com/v7/finance/download/BDX?period1=378604800&period2=1586476800&interval=1d&events=history
# BEAT
# https://query1.finance.yahoo.com/v7/finance/download/BEAT?period1=378604800&period2=1586476800&interval=1d&events=history
# BECN
# https://query1.finance.yahoo.com/v7/finance/download/BECN?period1=378604800&period2=1586476800&interval=1d&events=history
# BEL
# https://query1.finance.yahoo.com/v7/finance/download/BEL?period1=378604800&period2=1586476800&interval=1d&events=history
# BELFB
# https://query1.finance.yahoo.com/v7/finance/download/BELFB?period1=378604800&period2=1586476800&interval=1d&events=history
# BEN
# https://query1.finance.yahoo.com/v7/finance/download/BEN?period1=378604800&period2=1586476800&interval=1d&events=history
# BERY
# https://query1.finance.yahoo.com/v7/finance/download/BERY?period1=378604800&period2=1586476800&interval=1d&events=history
# BETR
# https://query1.finance.yahoo.com/v7/finance/download/BETR?period1=378604800&period2=1586476800&interval=1d&events=history
# BF.A
# https://query1.finance.yahoo.com/v7/finance/download/BF.A?period1=378604800&period2=1586476800&interval=1d&events=history
# BF.B
# https://query1.finance.yahoo.com/v7/finance/download/BF.B?period1=378604800&period2=1586476800&interval=1d&events=history
# BFAM
# https://query1.finance.yahoo.com/v7/finance/download/BFAM?period1=378604800&period2=1586476800&interval=1d&events=history
# BFIN
# https://query1.finance.yahoo.com/v7/finance/download/BFIN?period1=378604800&period2=1586476800&interval=1d&events=history
# BFS
# https://query1.finance.yahoo.com/v7/finance/download/BFS?period1=378604800&period2=1586476800&interval=1d&events=history
# BG
# https://query1.finance.yahoo.com/v7/finance/download/BG?period1=378604800&period2=1586476800&interval=1d&events=history
# BGC
# https://query1.finance.yahoo.com/v7/finance/download/BGC?period1=378604800&period2=1586476800&interval=1d&events=history
# BGCP
# https://query1.finance.yahoo.com/v7/finance/download/BGCP?period1=378604800&period2=1586476800&interval=1d&events=history
# BGFV
# https://query1.finance.yahoo.com/v7/finance/download/BGFV?period1=378604800&period2=1586476800&interval=1d&events=history
# BGG
# https://query1.finance.yahoo.com/v7/finance/download/BGG?period1=378604800&period2=1586476800&interval=1d&events=history
# BGS
# https://query1.finance.yahoo.com/v7/finance/download/BGS?period1=378604800&period2=1586476800&interval=1d&events=history
# BGSF
# https://query1.finance.yahoo.com/v7/finance/download/BGSF?period1=378604800&period2=1586476800&interval=1d&events=history
# BH
# https://query1.finance.yahoo.com/v7/finance/download/BH?period1=378604800&period2=1586476800&interval=1d&events=history
# BHB
# https://query1.finance.yahoo.com/v7/finance/download/BHB?period1=378604800&period2=1586476800&interval=1d&events=history
# BHBK
# https://query1.finance.yahoo.com/v7/finance/download/BHBK?period1=378604800&period2=1586476800&interval=1d&events=history
# BHE
# https://query1.finance.yahoo.com/v7/finance/download/BHE?period1=378604800&period2=1586476800&interval=1d&events=history
# BHI
# https://query1.finance.yahoo.com/v7/finance/download/BHI?period1=378604800&period2=1586476800&interval=1d&events=history
# BHLB
# https://query1.finance.yahoo.com/v7/finance/download/BHLB?period1=378604800&period2=1586476800&interval=1d&events=history
# BHP
# https://query1.finance.yahoo.com/v7/finance/download/BHP?period1=378604800&period2=1586476800&interval=1d&events=history
# BHVN
# https://query1.finance.yahoo.com/v7/finance/download/BHVN?period1=378604800&period2=1586476800&interval=1d&events=history
# BID
# https://query1.finance.yahoo.com/v7/finance/download/BID?period1=378604800&period2=1586476800&interval=1d&events=history
# BIG
# https://query1.finance.yahoo.com/v7/finance/download/BIG?period1=378604800&period2=1586476800&interval=1d&events=history
# BIIB
# https://query1.finance.yahoo.com/v7/finance/download/BIIB?period1=378604800&period2=1586476800&interval=1d&events=history
# BIO
# https://query1.finance.yahoo.com/v7/finance/download/BIO?period1=378604800&period2=1586476800&interval=1d&events=history
# BIOS
# https://query1.finance.yahoo.com/v7/finance/download/BIOS?period1=378604800&period2=1586476800&interval=1d&events=history
# BIP
# https://query1.finance.yahoo.com/v7/finance/download/BIP?period1=378604800&period2=1586476800&interval=1d&events=history
# BIVV
# https://query1.finance.yahoo.com/v7/finance/download/BIVV?period1=378604800&period2=1586476800&interval=1d&events=history
# BJRI
# https://query1.finance.yahoo.com/v7/finance/download/BJRI?period1=378604800&period2=1586476800&interval=1d&events=history
# BK
# https://query1.finance.yahoo.com/v7/finance/download/BK?period1=378604800&period2=1586476800&interval=1d&events=history
# BKD
# https://query1.finance.yahoo.com/v7/finance/download/BKD?period1=378604800&period2=1586476800&interval=1d&events=history
# BKE
# https://query1.finance.yahoo.com/v7/finance/download/BKE?period1=378604800&period2=1586476800&interval=1d&events=history
# BKFS
# https://query1.finance.yahoo.com/v7/finance/download/BKFS?period1=378604800&period2=1586476800&interval=1d&events=history
# BKH
# https://query1.finance.yahoo.com/v7/finance/download/BKH?period1=378604800&period2=1586476800&interval=1d&events=history
# BKMU
# https://query1.finance.yahoo.com/v7/finance/download/BKMU?period1=378604800&period2=1586476800&interval=1d&events=history
# BKNG
# https://query1.finance.yahoo.com/v7/finance/download/BKNG?period1=378604800&period2=1586476800&interval=1d&events=history
# BKR
# https://query1.finance.yahoo.com/v7/finance/download/BKR?period1=378604800&period2=1586476800&interval=1d&events=history
# BKS
# https://query1.finance.yahoo.com/v7/finance/download/BKS?period1=378604800&period2=1586476800&interval=1d&events=history
# BKU
# https://query1.finance.yahoo.com/v7/finance/download/BKU?period1=378604800&period2=1586476800&interval=1d&events=history
# BL
# https://query1.finance.yahoo.com/v7/finance/download/BL?period1=378604800&period2=1586476800&interval=1d&events=history
# BLBD
# https://query1.finance.yahoo.com/v7/finance/download/BLBD?period1=378604800&period2=1586476800&interval=1d&events=history
# BLCM
# https://query1.finance.yahoo.com/v7/finance/download/BLCM?period1=378604800&period2=1586476800&interval=1d&events=history
# BLD
# https://query1.finance.yahoo.com/v7/finance/download/BLD?period1=378604800&period2=1586476800&interval=1d&events=history
# BLDR
# https://query1.finance.yahoo.com/v7/finance/download/BLDR?period1=378604800&period2=1586476800&interval=1d&events=history
# BLK
# https://query1.finance.yahoo.com/v7/finance/download/BLK?period1=378604800&period2=1586476800&interval=1d&events=history
# BLKB
# https://query1.finance.yahoo.com/v7/finance/download/BLKB?period1=378604800&period2=1586476800&interval=1d&events=history
# BLL
# https://query1.finance.yahoo.com/v7/finance/download/BLL?period1=378604800&period2=1586476800&interval=1d&events=history
# BLMN
# https://query1.finance.yahoo.com/v7/finance/download/BLMN?period1=378604800&period2=1586476800&interval=1d&events=history
# BLMT
# ...
# VSAR
# https://query1.finance.yahoo.com/v7/finance/download/VSAR?period1=378604800&period2=1586476800&interval=1d&events=history
# VSAT
# https://query1.finance.yahoo.com/v7/finance/download/VSAT?period1=378604800&period2=1586476800&interval=1d&events=history
# VSEC
# https://query1.finance.yahoo.com/v7/finance/download/VSEC?period1=378604800&period2=1586476800&interval=1d&events=history
# VSH
# https://query1.finance.yahoo.com/v7/finance/download/VSH?period1=378604800&period2=1586476800&interval=1d&events=history
# VSI
# https://query1.finance.yahoo.com/v7/finance/download/VSI?period1=378604800&period2=1586476800&interval=1d&events=history
# VSLR
# https://query1.finance.yahoo.com/v7/finance/download/VSLR?period1=378604800&period2=1586476800&interval=1d&events=history
# VSM
# https://query1.finance.yahoo.com/v7/finance/download/VSM?period1=378604800&period2=1586476800&interval=1d&events=history
# VST
# https://query1.finance.yahoo.com/v7/finance/download/VST?period1=378604800&period2=1586476800&interval=1d&events=history
# VSTO
# https://query1.finance.yahoo.com/v7/finance/download/VSTO?period1=378604800&period2=1586476800&interval=1d&events=history
# VTI
# https://query1.finance.yahoo.com/v7/finance/download/VTI?period1=378604800&period2=1586476800&interval=1d&events=history
# VTR
# https://query1.finance.yahoo.com/v7/finance/download/VTR?period1=378604800&period2=1586476800&interval=1d&events=history
# VTVT
# https://query1.finance.yahoo.com/v7/finance/download/VTVT?period1=378604800&period2=1586476800&interval=1d&events=history
# VVC
# https://query1.finance.yahoo.com/v7/finance/download/VVC?period1=378604800&period2=1586476800&interval=1d&events=history
# VVI
# https://query1.finance.yahoo.com/v7/finance/download/VVI?period1=378604800&period2=1586476800&interval=1d&events=history
# VVV
# https://query1.finance.yahoo.com/v7/finance/download/VVV?period1=378604800&period2=1586476800&interval=1d&events=history
# VWR
# https://query1.finance.yahoo.com/v7/finance/download/VWR?period1=378604800&period2=1586476800&interval=1d&events=history
# VYGR
# https://query1.finance.yahoo.com/v7/finance/download/VYGR?period1=378604800&period2=1586476800&interval=1d&events=history
# VZ
# https://query1.finance.yahoo.com/v7/finance/download/VZ?period1=378604800&period2=1586476800&interval=1d&events=history
# W
# https://query1.finance.yahoo.com/v7/finance/download/W?period1=378604800&period2=1586476800&interval=1d&events=history
# WAAS
# https://query1.finance.yahoo.com/v7/finance/download/WAAS?period1=378604800&period2=1586476800&interval=1d&events=history
# WAB
# https://query1.finance.yahoo.com/v7/finance/download/WAB?period1=378604800&period2=1586476800&interval=1d&events=history
# WABC
# https://query1.finance.yahoo.com/v7/finance/download/WABC?period1=378604800&period2=1586476800&interval=1d&events=history
# WAFD
# https://query1.finance.yahoo.com/v7/finance/download/WAFD?period1=378604800&period2=1586476800&interval=1d&events=history
# WAGE
# https://query1.finance.yahoo.com/v7/finance/download/WAGE?period1=378604800&period2=1586476800&interval=1d&events=history
# WAIR
# https://query1.finance.yahoo.com/v7/finance/download/WAIR?period1=378604800&period2=1586476800&interval=1d&events=history
# WAL
# https://query1.finance.yahoo.com/v7/finance/download/WAL?period1=378604800&period2=1586476800&interval=1d&events=history
# WASH
# https://query1.finance.yahoo.com/v7/finance/download/WASH?period1=378604800&period2=1586476800&interval=1d&events=history
# WAT
# https://query1.finance.yahoo.com/v7/finance/download/WAT?period1=378604800&period2=1586476800&interval=1d&events=history
# WATT
# https://query1.finance.yahoo.com/v7/finance/download/WATT?period1=378604800&period2=1586476800&interval=1d&events=history
# WBA
# https://query1.finance.yahoo.com/v7/finance/download/WBA?period1=378604800&period2=1586476800&interval=1d&events=history
# WBC
# https://query1.finance.yahoo.com/v7/finance/download/WBC?period1=378604800&period2=1586476800&interval=1d&events=history
# WBK
# https://query1.finance.yahoo.com/v7/finance/download/WBK?period1=378604800&period2=1586476800&interval=1d&events=history
# WBMD
# https://query1.finance.yahoo.com/v7/finance/download/WBMD?period1=378604800&period2=1586476800&interval=1d&events=history
# WBS
# https://query1.finance.yahoo.com/v7/finance/download/WBS?period1=378604800&period2=1586476800&interval=1d&events=history
# WBT
# https://query1.finance.yahoo.com/v7/finance/download/WBT?period1=378604800&period2=1586476800&interval=1d&events=history
# WCC
# https://query1.finance.yahoo.com/v7/finance/download/WCC?period1=378604800&period2=1586476800&interval=1d&events=history
# WCG
# https://query1.finance.yahoo.com/v7/finance/download/WCG?period1=378604800&period2=1586476800&interval=1d&events=history
# WD
# https://query1.finance.yahoo.com/v7/finance/download/WD?period1=378604800&period2=1586476800&interval=1d&events=history
# WDAY
# https://query1.finance.yahoo.com/v7/finance/download/WDAY?period1=378604800&period2=1586476800&interval=1d&events=history
# WDC
# https://query1.finance.yahoo.com/v7/finance/download/WDC?period1=378604800&period2=1586476800&interval=1d&events=history
# WDFC
# https://query1.finance.yahoo.com/v7/finance/download/WDFC?period1=378604800&period2=1586476800&interval=1d&events=history
# WDR
# https://query1.finance.yahoo.com/v7/finance/download/WDR?period1=378604800&period2=1586476800&interval=1d&events=history
# WEB
# https://query1.finance.yahoo.com/v7/finance/download/WEB?period1=378604800&period2=1586476800&interval=1d&events=history
# WEC
# https://query1.finance.yahoo.com/v7/finance/download/WEC?period1=378604800&period2=1586476800&interval=1d&events=history
# WELL
# https://query1.finance.yahoo.com/v7/finance/download/WELL?period1=378604800&period2=1586476800&interval=1d&events=history
# WEN
# https://query1.finance.yahoo.com/v7/finance/download/WEN?period1=378604800&period2=1586476800&interval=1d&events=history
# WERN
# https://query1.finance.yahoo.com/v7/finance/download/WERN?period1=378604800&period2=1586476800&interval=1d&events=history
# WES
# https://query1.finance.yahoo.com/v7/finance/download/WES?period1=378604800&period2=1586476800&interval=1d&events=history
# WETF
# https://query1.finance.yahoo.com/v7/finance/download/WETF?period1=378604800&period2=1586476800&interval=1d&events=history
# WEX
# https://query1.finance.yahoo.com/v7/finance/download/WEX?period1=378604800&period2=1586476800&interval=1d&events=history
# WEYS
# https://query1.finance.yahoo.com/v7/finance/download/WEYS?period1=378604800&period2=1586476800&interval=1d&events=history
# WFBI
# https://query1.finance.yahoo.com/v7/finance/download/WFBI?period1=378604800&period2=1586476800&interval=1d&events=history
# WFC
# https://query1.finance.yahoo.com/v7/finance/download/WFC?period1=378604800&period2=1586476800&interval=1d&events=history
# WFM
# https://query1.finance.yahoo.com/v7/finance/download/WFM?period1=378604800&period2=1586476800&interval=1d&events=history
# WFT
# https://query1.finance.yahoo.com/v7/finance/download/WFT?period1=378604800&period2=1586476800&interval=1d&events=history
# WG
# https://query1.finance.yahoo.com/v7/finance/download/WG?period1=378604800&period2=1586476800&interval=1d&events=history
# WGL
# https://query1.finance.yahoo.com/v7/finance/download/WGL?period1=378604800&period2=1586476800&interval=1d&events=history
# WGO
# https://query1.finance.yahoo.com/v7/finance/download/WGO?period1=378604800&period2=1586476800&interval=1d&events=history
# WHG
# https://query1.finance.yahoo.com/v7/finance/download/WHG?period1=378604800&period2=1586476800&interval=1d&events=history
# WHR
# https://query1.finance.yahoo.com/v7/finance/download/WHR?period1=378604800&period2=1586476800&interval=1d&events=history
# WIFI
# https://query1.finance.yahoo.com/v7/finance/download/WIFI?period1=378604800&period2=1586476800&interval=1d&events=history
# WIN
# https://query1.finance.yahoo.com/v7/finance/download/WIN?period1=378604800&period2=1586476800&interval=1d&events=history
# WINA
# https://query1.finance.yahoo.com/v7/finance/download/WINA?period1=378604800&period2=1586476800&interval=1d&events=history
# WING
# https://query1.finance.yahoo.com/v7/finance/download/WING?period1=378604800&period2=1586476800&interval=1d&events=history
# WINS
# https://query1.finance.yahoo.com/v7/finance/download/WINS?period1=378604800&period2=1586476800&interval=1d&events=history
# WIRE
# https://query1.finance.yahoo.com/v7/finance/download/WIRE?period1=378604800&period2=1586476800&interval=1d&events=history
# WK
# https://query1.finance.yahoo.com/v7/finance/download/WK?period1=378604800&period2=1586476800&interval=1d&events=history
# WLB
# https://query1.finance.yahoo.com/v7/finance/download/WLB?period1=378604800&period2=1586476800&interval=1d&events=history
# WLDN
# https://query1.finance.yahoo.com/v7/finance/download/WLDN?period1=378604800&period2=1586476800&interval=1d&events=history
# WLFC
# https://query1.finance.yahoo.com/v7/finance/download/WLFC?period1=378604800&period2=1586476800&interval=1d&events=history
# WLH
# https://query1.finance.yahoo.com/v7/finance/download/WLH?period1=378604800&period2=1586476800&interval=1d&events=history
# WLK
# https://query1.finance.yahoo.com/v7/finance/download/WLK?period1=378604800&period2=1586476800&interval=1d&events=history
# WLL
# https://query1.finance.yahoo.com/v7/finance/download/WLL?period1=378604800&period2=1586476800&interval=1d&events=history
# WLTW
# https://query1.finance.yahoo.com/v7/finance/download/WLTW?period1=378604800&period2=1586476800&interval=1d&events=history
# WM
# https://query1.finance.yahoo.com/v7/finance/download/WM?period1=378604800&period2=1586476800&interval=1d&events=history
# WMAR
# https://query1.finance.yahoo.com/v7/finance/download/WMAR?period1=378604800&period2=1586476800&interval=1d&events=history
# WMB
# https://query1.finance.yahoo.com/v7/finance/download/WMB?period1=378604800&period2=1586476800&interval=1d&events=history
# WMC
# https://query1.finance.yahoo.com/v7/finance/download/WMC?period1=378604800&period2=1586476800&interval=1d&events=history
# WMGI
# https://query1.finance.yahoo.com/v7/finance/download/WMGI?period1=378604800&period2=1586476800&interval=1d&events=history
# WMIH
# https://query1.finance.yahoo.com/v7/finance/download/WMIH?period1=378604800&period2=1586476800&interval=1d&events=history
# WMK
# https://query1.finance.yahoo.com/v7/finance/download/WMK?period1=378604800&period2=1586476800&interval=1d&events=history
# WMS
# https://query1.finance.yahoo.com/v7/finance/download/WMS?period1=378604800&period2=1586476800&interval=1d&events=history
# WMT
# https://query1.finance.yahoo.com/v7/finance/download/WMT?period1=378604800&period2=1586476800&interval=1d&events=history
# WNC
# https://query1.finance.yahoo.com/v7/finance/download/WNC?period1=378604800&period2=1586476800&interval=1d&events=history
# WNEB
# https://query1.finance.yahoo.com/v7/finance/download/WNEB?period1=378604800&period2=1586476800&interval=1d&events=history
# WOOF
# https://query1.finance.yahoo.com/v7/finance/download/WOOF?period1=378604800&period2=1586476800&interval=1d&events=history
# WOR
# https://query1.finance.yahoo.com/v7/finance/download/WOR?period1=378604800&period2=1586476800&interval=1d&events=history
# WPC
# https://query1.finance.yahoo.com/v7/finance/download/WPC?period1=378604800&period2=1586476800&interval=1d&events=history
# WPG
# https://query1.finance.yahoo.com/v7/finance/download/WPG?period1=378604800&period2=1586476800&interval=1d&events=history
# WPX
# https://query1.finance.yahoo.com/v7/finance/download/WPX?period1=378604800&period2=1586476800&interval=1d&events=history
# WR
# https://query1.finance.yahoo.com/v7/finance/download/WR?period1=378604800&period2=1586476800&interval=1d&events=history
# WRB
# https://query1.finance.yahoo.com/v7/finance/download/WRB?period1=378604800&period2=1586476800&interval=1d&events=history
# WRD
# https://query1.finance.yahoo.com/v7/finance/download/WRD?period1=378604800&period2=1586476800&interval=1d&events=history
# WRE
# https://query1.finance.yahoo.com/v7/finance/download/WRE?period1=378604800&period2=1586476800&interval=1d&events=history
# WRI
# https://query1.finance.yahoo.com/v7/finance/download/WRI?period1=378604800&period2=1586476800&interval=1d&events=history
# WRK
# https://query1.finance.yahoo.com/v7/finance/download/WRK?period1=378604800&period2=1586476800&interval=1d&events=history
# WRLD
# https://query1.finance.yahoo.com/v7/finance/download/WRLD?period1=378604800&period2=1586476800&interval=1d&events=history
# WSBC
# https://query1.finance.yahoo.com/v7/finance/download/WSBC?period1=378604800&period2=1586476800&interval=1d&events=history
# WSBF
# https://query1.finance.yahoo.com/v7/finance/download/WSBF?period1=378604800&period2=1586476800&interval=1d&events=history
# WSFS
# https://query1.finance.yahoo.com/v7/finance/download/WSFS?period1=378604800&period2=1586476800&interval=1d&events=history
# WSM
# https://query1.finance.yahoo.com/v7/finance/download/WSM?period1=378604800&period2=1586476800&interval=1d&events=history
# WSO
# https://query1.finance.yahoo.com/v7/finance/download/WSO?period1=378604800&period2=1586476800&interval=1d&events=history
# WSR
# https://query1.finance.yahoo.com/v7/finance/download/WSR?period1=378604800&period2=1586476800&interval=1d&events=history
# WST
# https://query1.finance.yahoo.com/v7/finance/download/WST?period1=378604800&period2=1586476800&interval=1d&events=history
# WTFC
# https://query1.finance.yahoo.com/v7/finance/download/WTFC?period1=378604800&period2=1586476800&interval=1d&events=history
# WU
# https://query1.finance.yahoo.com/v7/finance/download/WU?period1=378604800&period2=1586476800&interval=1d&events=history
# WY
# https://query1.finance.yahoo.com/v7/finance/download/WY?period1=378604800&period2=1586476800&interval=1d&events=history
# WYNN
# https://query1.finance.yahoo.com/v7/finance/download/WYNN?period1=378604800&period2=1586476800&interval=1d&events=history
# XEC
# https://query1.finance.yahoo.com/v7/finance/download/XEC?period1=378604800&period2=1586476800&interval=1d&events=history
# XEL
# https://query1.finance.yahoo.com/v7/finance/download/XEL?period1=378604800&period2=1586476800&interval=1d&events=history
# XHR
# https://query1.finance.yahoo.com/v7/finance/download/XHR?period1=378604800&period2=1586476800&interval=1d&events=history
# XLF
# https://query1.finance.yahoo.com/v7/finance/download/XLF?period1=378604800&period2=1586476800&interval=1d&events=history
# XLNX
# https://query1.finance.yahoo.com/v7/finance/download/XLNX?period1=378604800&period2=1586476800&interval=1d&events=history
# XOM
# https://query1.finance.yahoo.com/v7/finance/download/XOM?period1=378604800&period2=1586476800&interval=1d&events=history
# XRAY
# https://query1.finance.yahoo.com/v7/finance/download/XRAY?period1=378604800&period2=1586476800&interval=1d&events=history
# XRX
# https://query1.finance.yahoo.com/v7/finance/download/XRX?period1=378604800&period2=1586476800&interval=1d&events=history
# XYL
# https://query1.finance.yahoo.com/v7/finance/download/XYL?period1=378604800&period2=1586476800&interval=1d&events=history
# YPF
# https://query1.finance.yahoo.com/v7/finance/download/YPF?period1=378604800&period2=1586476800&interval=1d&events=history
# YUM
# https://query1.finance.yahoo.com/v7/finance/download/YUM?period1=378604800&period2=1586476800&interval=1d&events=history
# ZBH
# https://query1.finance.yahoo.com/v7/finance/download/ZBH?period1=378604800&period2=1586476800&interval=1d&events=history
# ZBRA
# https://query1.finance.yahoo.com/v7/finance/download/ZBRA?period1=378604800&period2=1586476800&interval=1d&events=history
# ZION
# https://query1.finance.yahoo.com/v7/finance/download/ZION?period1=378604800&period2=1586476800&interval=1d&events=history
# ZTS
# https://query1.finance.yahoo.com/v7/finance/download/ZTS?period1=378604800&period2=1586476800&interval=1d&events=history
# ^DJI
# https://query1.finance.yahoo.com/v7/finance/download/^DJI?period1=378604800&period2=1586476800&interval=1d&events=history
# ^GSPC
# https://query1.finance.yahoo.com/v7/finance/download/^GSPC?period1=378604800&period2=1586476800&interval=1d&events=history
# ^IXIC
# https://query1.finance.yahoo.com/v7/finance/download/^IXIC?period1=378604800&period2=1586476800&interval=1d&events=history
# ^TNX
# https://query1.finance.yahoo.com/v7/finance/download/^TNX?period1=378604800&period2=1586476800&interval=1d&events=history

# %%
master_px_frame.describe()
# Out:
#           adj_close         close         delta          high           low  \
# count  1.443555e+07  1.443555e+07  1.443555e+07  1.443555e+07  1.443555e+07
# mean  -1.209828e+17  7.130632e+01  9.924559e+00  7.254603e+01  7.019005e+01
# std    1.426692e+19  1.469913e+03  9.937393e+02  1.498947e+03  1.450090e+03
# min   -2.380501e+21  0.000000e+00 -1.500000e+04  0.000000e+00  0.000000e+00
# 25%    5.425534e+00  8.360000e+00 -1.599990e-01  8.500000e+00  8.210000e+00
# 50%    1.388438e+01  1.830000e+01  0.000000e+00  1.857000e+01  1.800000e+01
# 75%    2.977434e+01  3.576000e+01  2.399980e-01  3.625000e+01  3.525000e+01
# max    1.883516e+19  2.148876e+05  2.148876e+05  2.148876e+05  2.134831e+05
#
#                open        volume
# count  1.443555e+07  1.443555e+07
# mean   6.138176e+01  3.654067e+06
# std    1.088643e+03  7.623203e+07
# min    0.000000e+00  0.000000e+00
# 25%    8.000000e+00  4.520000e+04
# 50%    1.812500e+01  2.484000e+05
# 75%    3.559000e+01  1.003000e+06
# max    1.825000e+05  1.145623e+10

# %%
master_px_frame.shape
# Out:
# (14435547, 9)
